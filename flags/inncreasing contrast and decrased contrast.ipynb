# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\6.jpg")

# %%
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\6.jpg", cv2.IMREAD_GRAYSCALE)  # Load as grayscale for simplicity

# Increase contrast using histogram equalization
equalized_image = cv2.equalizeHist(image)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg", equalized_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)
# Out:
# اماد ع0 27652800115
# 56لاع 16 ةذزا/ااهم ‎(١‏

# %%
import numpy as np

# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\6.jpg")

# Define the desired contrast reduction factors (adjust as needed)
alpha = 0.5  # Decrease contrast
beta = 127   # Adjust brightness

# Apply contrast reduction
adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg", adjusted_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)
# Out:
# الجمهورية اللبنانية
#
# وزارة الداخلية بطاقة هوية 2 ظ
# الاسم : ياسعيين
#
# الشهرة: العمري
#
# اسم الاب : محمد
#
# محل الولادة : باينه -
# تاريخ الولادة:4 ‎١991//117/1‏
#
# إ رما اباي د
# انوا صاحب العلاقة' هي سل :

# %%
# Define keywords to identify fields
field_keywords = {
    'name': ['الاسم'],
    'address': ['اسم الاب'],
    'dob': ['تاريخ الولادة']
}

# Extract specific fields based on keywords
data = {}
for field, keywords in field_keywords.items():
    for keyword in keywords:
        if keyword in text.lower():
            start_index = text.lower().index(keyword)
            end_index = start_index + len(keyword)
            actual_text = text[end_index:].strip()
           
           
 
           
            data[field] = actual_text[:end_index].strip()
            break

# Print the extracted data
print("Extracted Data:")
print("Name:", data.get('name', 'Not found'))
print("Address:", data.get('address', 'Not found'))
print("Date of Birth:", data.get('dob', 'Not found'))
# Out:
# Extracted Data:
# Name: : ياسعيين
#
# الشهرة: العمري
#
# اسم الاب : محمد
#
# محل الولادة
# Address: : محمد
#
# محل الولادة : باينه -
# تاريخ الولادة:4 ‎١991//117/1‏
#
# إ رما اباي د
# انوا صاحب العلاقة'
# Date of Birth: :4 ‎١991//117/1‏
#
# إ رما اباي د
# انوا صاحب العلاقة' هي سل :

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\1.WEBP")

# %%
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\1.WEBP", cv2.IMREAD_GRAYSCALE)  # Load as grayscale for simplicity

# Increase contrast using histogram equalization
equalized_image = cv2.equalizeHist(image)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg", equalized_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)

# %%
import numpy as np

# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\1.WEBP")

# Define the desired contrast reduction factors (adjust as needed)
alpha = 0.5  # Decrease contrast
beta = 127   # Adjust brightness

# Apply contrast reduction
adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg", adjusted_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)
# Out:
# جخمهور. ية اللبنانية
# د الداخلية
# لات عير
# الشهرة: العاصي
# اسم الاب :.حسن
# اسم الام وشهزكها ؛ لظيفه البخاري
#
# محل الولادة :.صيدا
# تاريخ الولادةبه 5[ | كوو
#
# الاو
#
# توقيع صاحب العلاقة

# %%
# Define keywords to identify fields
field_keywords = {
    'name': ['الاسم'],
    'address': ['اسم الاب'],
    'dob': ['تاريخ الولادة']
}

# Extract specific fields based on keywords
data = {}
for field, keywords in field_keywords.items():
    for keyword in keywords:
        if keyword in text.lower():
            start_index = text.lower().index(keyword)
            end_index = start_index + len(keyword)
            actual_text = text[end_index:].strip()
           
           
 
           
            data[field] = actual_text[:end_index].strip()
            break

# Print the extracted data
print("Extracted Data:")
print("Name:", data.get('name', 'Not found'))
print("Address:", data.get('address', 'Not found'))
print("Date of Birth:", data.get('dob', 'Not found'))
# Out:
# Extracted Data:
# Name: Not found
# Address: :.حسن
# اسم الام وشهزكها ؛ لظيفه البخاري
#
# محل الولادة :.صيدا
# تاري
# Date of Birth: به 5[ | كوو
#
# الاو
#
# توقيع صاحب العلاقة

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\2.jpg")

# %%
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\2.jpg", cv2.IMREAD_GRAYSCALE)  # Load as grayscale for simplicity

# Increase contrast using histogram equalization
equalized_image = cv2.equalizeHist(image)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg", equalized_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)
# Out:
# اماد ع0 27652800115
# 56لاع 16 ةذزا/ااهم ‎(١‏

# %%
import numpy as np

# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\2.jpg")

# Define the desired contrast reduction factors (adjust as needed)
alpha = 0.5  # Decrease contrast
beta = 127   # Adjust brightness

# Apply contrast reduction
adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg", adjusted_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\decreased_contrast_image.jpg")

# %%
text=pytesseract.image_to_string(img,lang="ara")

# %%
print(text)
# Out:
# ل 397 وه 0
#
# 6011010186 ع0 :5681115 عكلقلامون عناوا لمعم 7
# 6156 مللالااممة لونيوية ع0 علاقامعم8
#
# 07ر0 ...ل وزارة الداخلية والبلديات -مينة إدارة السير والأليات والمركبات
# 67 به نورالدن 2 1
#
# تلن نينا
# ماري جوزيفا2 .2
#
# منامع 05ل - ع1 عم"
# بيروت 8818101 07/04/1963 2 .3
# 25
# 105 .مه
#
# هيتة إدارة السير والاليات والمركيات .46
# 840065عنا نبتقية .138
#
# مضطفى علي .136
#
# بناية عيلا شارع اد ونيس الحمرابير وت .8
#
# لا ادا إن[ 07 راس بير وت مقابل جامع شاتيلا د
#
# »** #ع5ها 00011141 ع 10 616 11. 9
# سس يسيس اس سجس جم ص متا ء ومس اوباحت مانس بس د
#
# وبي رخصة سير مركبة آلبة /5240 اكات اخه
#
# كقاظائافقنلا عنا0ااقنامع8
# وزارة الداخلية والإلديات _ هينة/ غلك لست ناتيت المع 06 6نامع
#
# إخولية مني عليانة خصصعص وجح سؤاست متت عع

# %%
import  matplotlib.pyplot as plt
# %matplotlib inline
def show(img):
    plt.imshow(img)
    plt.show()
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\6.jpg")
show(image)

# Define a brightness factor (adjust this value as needed)
brightness_factor = 50

# Increase brightness using cv2.addWeighted
brightened_image = cv2.addWeighted(image, 1 + (brightness_factor / 100), image, 0, 0)
show(brightened_image)
# Clip pixel values to the valid range (0-255)
#brightened_image = cv2.clip(brightened_image, 0, 255)

# Save the brightened image
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\brightened_image.jpg", brightened_image)
# Out:
# True

# %%
import  matplotlib.pyplot as plt
# %matplotlib inline
def show(img):
    plt.imshow(img)
    plt.show()
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\brightened_image.jpg",brightened_image)
show(image)
import numpy as np

# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\6.jpg")

# Define a contrast factor (adjust this value as needed)
contrast_factor = 0.5  # Values less than 1 will decrease contrast

# Calculate the new image with decreased contrast
adjusted_image = np.uint8(np.clip(image * contrast_factor, 0, 255))


# Save the adjusted image
cv2.imwrite('decreased_contrast_image.jpg', adjusted_image)
show(adjusted_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5     plt.show()
#       6 # Load the image
# ----> 7 image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\brightened_image.jpg",brightened_image)
#       8 show(image)
#       9 import numpy as np
#
# TypeError: Argument 'flags' is required to be an integer

# %%
# Load the image
image = cv2.imread(r"C:\Users\MY PC\Desktop\flags\brightened_image.jpg", cv2.IMREAD_GRAYSCALE)  # Load as grayscale for simplicity

# Increase contrast using histogram equalization
equalized_image = cv2.equalizeHist(image)

# Save the result
cv2.imwrite(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg", equalized_image)
# Out:
# True

# %%
img=cv2.imread(r"C:\Users\MY PC\Desktop\flags\increased_contrast_image.jpg")
text=pytesseract.image_to_string(img,lang="ara")
print(text)
# Out:
# للبنانية
# الجمهورية ل
#
# خلية
# وزارة الد1
